# %% [markdown]
# **Importing Libraries**

# %%
pip install folium matplotlib mapclassify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline
import shapely
from shapely.geometry import Point, LineString, Polygon
import mapclassify
import folium

# %% [markdown]
# **Adding Vector Data**

# %%
municipality = gpd.read_file("/content/drive/MyDrive/Geospatial analysis project /Data/municipality.shp")

# %%
municipality_geojson = gpd.read_file("/content/drive/MyDrive/Geospatial analysis project /Data/municipality.geojson")

# %%
len(municipality)
# Out:
# 775

# %%
 municipality.head()
# Out:
#    PROVINCE        PR_NAME   DISTRICT           PALIKA        TYPE  \
# 0         1  Province No 1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika
# 1         1  Province No 1  TAPLEJUNG       Maiwakhola  Gaunpalika
# 2         1  Province No 1  TAPLEJUNG        Meringden  Gaunpalika
# 3         1  Province No 1  TAPLEJUNG       Mikwakhola  Gaunpalika
# 4         1  Province No 1  TAPLEJUNG     Phaktanglung  Gaunpalika
#
#                                             geometry
# 0  POLYGON ((87.60985 27.37043, 87.61107 27.36943...
# 1  POLYGON ((87.50402 27.42901, 87.50672 27.42831...
# 2  POLYGON ((87.51233 27.56818, 87.51196 27.56768...
# 3  POLYGON ((87.66620 27.73004, 87.66659 27.73000...
# 4  POLYGON ((87.83673 27.95137, 87.83735 27.95119...

# %%
municipality.geom_type
# Out:
# 0      Polygon
# 1      Polygon
# 2      Polygon
# 3      Polygon
# 4      Polygon
#         ...
# 770    Polygon
# 771    Polygon
# 772    Polygon
# 773    Polygon
# 774    Polygon
# Length: 775, dtype: object

# %%
 municipality.shape
# Out:
# (775, 6)

# %%
municipality.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
type(municipality)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# **Visualizing our Data**

# %%
 # Plotting the municiplaities using matplotlib
 municipality.plot()
# Out:
# <AxesSubplot:>

# %%
# Just showing the boundaries of each municiplaity
municipality.boundary.plot(figsize = (10,10))
# Out:
# <AxesSubplot:>

# %%
# Giving Different colour to each province
municipality.plot("PR_NAME", cmap = "magma", legend = True, figsize = (10,10)).set_axis_off()

# %% [markdown]
# **Writing Data**

# %%
new_file = gpd.read_file("/content/drive/MyDrive/Geospatial analysis project /Data/municipality.shp")

# %%
new_file.to_file("/content/drive/MyDrive/Geospatial analysis project /Output/municipality.shp")

# %%
new_file.to_file("/content/drive/MyDrive/Geospatial analysis project /Output/municipality.geojson", driver = "GeoJSON", encoding = "utf-8")

# %%
new_file.to_file("/content/drive/MyDrive/Geospatial analysis project /Output/municipality.gpkg", driver = "GPKG", layer = "palika", encoding = "utf-8")

# %% [markdown]
# **Working with attribute data**

# %%
rupandehi = municipality[municipality["DISTRICT"] == "RUPANDEHI"]

# %%
rupandehi.plot(figsize = (10,10))
# Out:
# <AxesSubplot:>

# %%
rupandehi.head()
# Out:
#      PROVINCE        PR_NAME   DISTRICT     PALIKA                TYPE  \
# 509         5  Province No 5  RUPANDEHI     Butwal  Upamahanagarpalika
# 510         5  Province No 5  RUPANDEHI    Devdaha         Nagarpalika
# 511         5  Province No 5  RUPANDEHI  Gaidahawa          Gaunpalika
# 512         5  Province No 5  RUPANDEHI    Kanchan          Gaunpalika
# 513         5  Province No 5  RUPANDEHI  Kotahimai          Gaunpalika
#
#                                               geometry
# 509  POLYGON ((83.39404 27.74746, 83.39444 27.74707...
# 510  POLYGON ((83.50562 27.72572, 83.50622 27.72560...
# 511  POLYGON ((83.32845 27.65126, 83.32876 27.65095...
# 512  POLYGON ((83.26076 27.69161, 83.26059 27.68940...
# 513  POLYGON ((83.33693 27.48945, 83.33803 27.48927...

# %%
len(rupandehi)
# Out:
# 17

# %%
rupandehi.shape
# Out:
# (17, 6)

# %%
rupandehi.plot("PALIKA",cmap='magma')
# Out:
# <AxesSubplot:>

# %%
municipality1=gpd.read_file("/content/drive/MyDrive/Geospatial analysis project /Output/municipality.shp")

# %%
municipality1.head()
# Out:
#    PROVINCE        PR_NAME   DISTRICT           PALIKA        TYPE  \
# 0         1  Province No 1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika
# 1         1  Province No 1  TAPLEJUNG       Maiwakhola  Gaunpalika
# 2         1  Province No 1  TAPLEJUNG        Meringden  Gaunpalika
# 3         1  Province No 1  TAPLEJUNG       Mikwakhola  Gaunpalika
# 4         1  Province No 1  TAPLEJUNG     Phaktanglung  Gaunpalika
#
#                                             geometry
# 0  POLYGON ((87.60985 27.37043, 87.61107 27.36943...
# 1  POLYGON ((87.50402 27.42901, 87.50672 27.42831...
# 2  POLYGON ((87.51233 27.56818, 87.51196 27.56768...
# 3  POLYGON ((87.66620 27.73004, 87.66659 27.73000...
# 4  POLYGON ((87.83673 27.95137, 87.83735 27.95119...

# %%
municipality1['area']=0

# %%
municipality1.head()
# Out:
#    PROVINCE        PR_NAME   DISTRICT           PALIKA        TYPE  \
# 0         1  Province No 1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika
# 1         1  Province No 1  TAPLEJUNG       Maiwakhola  Gaunpalika
# 2         1  Province No 1  TAPLEJUNG        Meringden  Gaunpalika
# 3         1  Province No 1  TAPLEJUNG       Mikwakhola  Gaunpalika
# 4         1  Province No 1  TAPLEJUNG     Phaktanglung  Gaunpalika
#
#                                             geometry  area
# 0  POLYGON ((87.60985 27.37043, 87.61107 27.36943...     0
# 1  POLYGON ((87.50402 27.42901, 87.50672 27.42831...     0
# 2  POLYGON ((87.51233 27.56818, 87.51196 27.56768...     0
# 3  POLYGON ((87.66620 27.73004, 87.66659 27.73000...     0
# 4  POLYGON ((87.83673 27.95137, 87.83735 27.95119...     0

# %%
municipality_crs = municipality1.to_crs(epsg=32645)

# %%
municipality_crs['area']=municipality_crs.geometry.area / 10**6

# %%
municipality_crs.head()
# Out:
#    PROVINCE        PR_NAME   DISTRICT           PALIKA        TYPE  \
# 0         1  Province No 1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika
# 1         1  Province No 1  TAPLEJUNG       Maiwakhola  Gaunpalika
# 2         1  Province No 1  TAPLEJUNG        Meringden  Gaunpalika
# 3         1  Province No 1  TAPLEJUNG       Mikwakhola  Gaunpalika
# 4         1  Province No 1  TAPLEJUNG     Phaktanglung  Gaunpalika
#
#                                             geometry         area
# 0  POLYGON ((560307.153 3027612.864, 560428.320 3...    88.521700
# 1  POLYGON ((549815.446 3034054.303, 550082.592 3...   137.371061
# 2  POLYGON ((550573.020 3049473.152, 550537.274 3...   209.626709
# 3  POLYGON ((565665.744 3067475.242, 565704.431 3...   441.435863
# 4  POLYGON ((582308.234 3092096.983, 582369.345 3...  1851.420797

# %%
municipality_crs.plot('area',legend=True)
# Out:
# <AxesSubplot:>

# %%
plot_palpa = municipality[municipality['DISTRICT']=='PALPA']

# %%
plot_palpa.plot()
# Out:
# <AxesSubplot:>

# %%
ax = rupandehi.plot(figsize=(10,10))
plot_palpa.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
rupandehi.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
rupandehi.explore(column='PALIKA',cmap='magma')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
